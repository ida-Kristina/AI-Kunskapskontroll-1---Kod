# %%
import json
from retriever import MatematikRetriever
from generator import MatematikGenerator

# %%
# %%
# VERIFIERA KLASSNAMN
import retriever
print("Klasser i retriever.py:")
print([name for name in dir(retriever) if 'Retriever' in name])

import generator  
print("Klasser i generator.py:")
print([name for name in dir(generator) if 'Generator' in name])
# Out:
# Klasser i retriever.py:
# ['MatematikRetriever']
# Klasser i generator.py:
# ['MatematikGenerator']

# %%
# %%
# FELfelsökning: Importer + Filstruktur
import os
import sys

print("🐛 FELFELSÖKNING: Python-moduler")
print(f"Nuvarande mapp: {os.getcwd()}")
print(f"Python path: {sys.path[:3]}")  # Första 3 sökvägar

# Lista filer i mappen
print("\n📁 Filer i din mapp:")
for file in os.listdir("."):
    if file.endswith((".py", ".ipynb")):
        print(f"  {file}")

# %%
# TEST 1: Finns filerna?
retriever_exists = os.path.exists("retriever.py")
generator_exists = os.path.exists("generator.py")

print(f"✅ retriever.py: {'JA' if retriever_exists else 'NEJ ❌'}")
print(f"✅ generator.py: {'JA' if generator_exists else 'NEJ ❌'}")

if not retriever_exists:
    print("🔴 SKAPA retriever.py först!")
if not generator_exists: 
    print("🔴 SKAPA generator.py först!")
